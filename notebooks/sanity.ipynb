# %%
import pandas as pd
import os

# %%
DIR = r'../data/'
TFC1 = os.path.join(DIR, 'TFC1-data.tsv.gz')
TDC = os.path.join(DIR, 'TDC-data.tsv.gz')
DELTA_SANITY = os.path.join(DIR, 'topk', '')

# %%
TFC1_frame = pd.read_csv(TFC1, sep='\t', compression='gzip')
TDC_frame = pd.read_csv(TDC, sep='\t', compression='gzip')

# %%
TFC1_frame
# Out:
#            qid                                              query    docno  \
# 0        19335          anthropological definition of environment  1017759
# 1        19335          anthropological definition of environment  1082489
# 2        19335          anthropological definition of environment   109063
# 3        19335          anthropological definition of environment  1160863
# 4        19335          anthropological definition of environment  1160871
# ...        ...                                                ...      ...
# 41287  1136962  why did the ancient egyptians call their land ...  8526087
# 41288  1136962  why did the ancient egyptians call their land ...  8537921
# 41289  1136962  why did the ancient egyptians call their land ...  8742482
# 41290  1136962  why did the ancient egyptians call their land ...   937258
# 41291  1136962  why did the ancient egyptians call their land ...   999215
#
# ...
